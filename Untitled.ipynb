# %%
#Se importan las librerias 

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# /anaconda3/lib/python3.6/site-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#data = pd.read_csv('/Users/rodolfopardo/Downloads/YouTube Users google cloud(1).csv')
#data2 = pd.read_csv('/Users/rodolfopardo/Downloads/YouTube Users google cloud(2).csv')
#data3 = pd.read_csv('/Users/rodolfopardo/Downloads/YouTube Users google cloud.csv')
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0x92 in position 2: invalid start byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# <ipython-input-6-a7d7014fdd35> in <module>
#       1 #data = pd.read_csv('/Users/rodolfopardo/Downloads/YouTube Users google cloud(1).csv')
#       2 #data2 = pd.read_csv('/Users/rodolfopardo/Downloads/YouTube Users google cloud(2).csv')
# ...

# %%
data.head()
# Out:
#    Group  Vertex Color  Vertex Shape  Visibility  Collapsed?  Label  \
# 0    NaN           NaN           NaN         NaN         NaN    NaN
# 1    NaN           NaN           NaN         NaN         NaN    NaN
# 2    NaN           NaN           NaN         NaN         NaN    NaN
# 3    NaN           NaN           NaN         NaN         NaN    NaN
# 4    NaN           NaN           NaN         NaN         NaN    NaN
#
#    Collapsed X  Collapsed Y  ID  Collapsed Properties  ...  Self-Loops  \
# 0          NaN          NaN NaN                   NaN  ...         NaN
# 1          NaN          NaN NaN                   NaN  ...         NaN
# 2          NaN          NaN NaN                   NaN  ...         NaN
# 3          NaN          NaN NaN                   NaN  ...         NaN
# 4          NaN          NaN NaN                   NaN  ...         NaN
#
#    Reciprocated Vertex Pair Ratio  Reciprocated Edge Ratio  \
# 0                             NaN                      NaN
# ...
